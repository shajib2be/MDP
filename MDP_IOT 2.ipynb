# %%
import math
import gym
from gym import spaces, logger
from gym.utils import seeding
import numpy as np
import random


class CartPoleEnv(gym.Env):
    """
    Description:
        A pole is attached by an un-actuated joint to a cart, which moves along
        a frictionless track. The pendulum starts upright, and the goal is to
        prevent it from falling over by increasing and reducing the cart's
        velocity.
    Source:
        This environment corresponds to the version of the cart-pole problem
        described by Barto, Sutton, and Anderson
    Observation:
        Type: Box(4)
        Num     Observation               Min                     Max
        0       Cart Position             -4.8                    4.8
        1       Cart Velocity             -Inf                    Inf
        2       Pole Angle                -0.418 rad (-24 deg)    0.418 rad (24 deg)
        3       Pole Angular Velocity     -Inf                    Inf
    Actions:
        Type: Discrete(2)
        Num   Action
        0     Push cart to the left
        1     Push cart to the right
        Note: The amount the velocity that is reduced or increased is not
        fixed; it depends on the angle the pole is pointing. This is because
        the center of gravity of the pole increases the amount of energy needed
        to move the cart underneath it
    Reward:
        Reward is 1 for every step taken, including the termination step
    Starting State:
        All observations are assigned a uniform random value in [-0.05..0.05]
    Episode Termination:
        Pole Angle is more than 12 degrees.
        Cart Position is more than 2.4 (center of the cart reaches the edge of
        the display).
        Episode length is greater than 200.
        Solved Requirements:
        Considered solved when the average return is greater than or equal to
        195.0 over 100 consecutive trials.
    """

    #metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 50}

    def __init__(self):
        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates
        self.kinematics_integrator = "euler"

        # Angle at which to fail the episode
        #self.theta_threshold_radians = 12 * 2 * math.pi / 360
        #self.x_threshold = 2.4

        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array(
            [
                160,
                10,
                 10,
                10,
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.seed()
        self.viewer = None
        self.state = None

        self.steps_beyond_done = None

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def step(self, action):
        err_msg = "%r (%s) invalid" % (action, type(action))
        assert self.action_space.contains(action), err_msg
        
        
        
        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        

        r=random.choices(t)
        r[0][0], r[0][1], r[0][2], r[0][2] = self.state
        r[0][1]=r[0][1]+1
        self.state = (r[0][0], r[0][1], r[0][2], r[0][2])

        done=bool(r[0][0]==1)

        if not done:
            reward = 1.0
        elif self.steps_beyond_done is None:
            # Pole just fell!
            self.steps_beyond_done = 0
            reward = 1.0
        
        return np.array(self.state, dtype=np.float32), reward, done, {}

    def reset(self):
        self.state = self.np_random.uniform(low=-0.05, high=0.05, size=(4,))
        self.steps_beyond_done = None
        return np.array(self.state, dtype=np.float32)

# %%
"""
Classic cart-pole system implemented by Rich Sutton et al.
Copied from http://incompleteideas.net/sutton/book/code/pole.c
permalink: https://perma.cc/C9ZM-652R
"""

import math
import gym
from gym import spaces, logger
from gym.utils import seeding
import numpy as np
import random


class CartPoleEnv1(gym.Env):
    """
    Description:
        A pole is attached by an un-actuated joint to a cart, which moves along
        a frictionless track. The pendulum starts upright, and the goal is to
        prevent it from falling over by increasing and reducing the cart's
        velocity.
    Source:
        This environment corresponds to the version of the cart-pole problem
        described by Barto, Sutton, and Anderson
    Observation:
        Type: Box(4)
        Num     Observation               Min                     Max
        0       Cart Position             -4.8                    4.8
        1       Cart Velocity             -Inf                    Inf
        2       Pole Angle                -0.418 rad (-24 deg)    0.418 rad (24 deg)
        3       Pole Angular Velocity     -Inf                    Inf
    Actions:
        Type: Discrete(2)
        Num   Action
        0     Push cart to the left
        1     Push cart to the right
        Note: The amount the velocity that is reduced or increased is not
        fixed; it depends on the angle the pole is pointing. This is because
        the center of gravity of the pole increases the amount of energy needed
        to move the cart underneath it
    Reward:
        Reward is 1 for every step taken, including the termination step
    Starting State:
        All observations are assigned a uniform random value in [-0.05..0.05]
    Episode Termination:
        Pole Angle is more than 12 degrees.
        Cart Position is more than 2.4 (center of the cart reaches the edge of
        the display).
        Episode length is greater than 200.
        Solved Requirements:
        Considered solved when the average return is greater than or equal to
        195.0 over 100 consecutive trials.
    """

    #metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 50}

    def __init__(self):
        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates
        self.kinematics_integrator = "euler"

        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4

        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array(
            [
                1,
                100,
                100,
                100,
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.seed()
        self.viewer = None
        self.state = None

        self.steps_beyond_done = None

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def step(self, action):
        err_msg = "%r (%s) invalid" % (action, type(action))
        assert self.action_space.contains(action), err_msg

        x, x_dot, theta, theta_dot = self.state
        i=1
         
        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        
        #t=[1,5,4]
        reward=0
        a=5
        b=5
        
        
        #for i in range(20):
        
        if random.random()>math.exp(-a/b):
            x=0
            x_dot = 3
            theta = 3
            theta_dot = 4
            reward = -1
            b+=1
            a-=1
            
            
            
            
            
        else:
            x = 1
            x_dot =x_dot+i
            theta = 3
            theta_dot = 4
            
            
            
            i+=1
            reward = 1
        #if self.kinematics_integrator == "euler":
        #x = t[0][0]
        
          
        self.state = (x, x_dot, theta, theta_dot)

        done = bool(x_dot>40)
        
        a=a
        b=b
       
        

        return np.array(self.state, dtype=np.float32), reward, done, {}


    def reset(self):
        
        #self.state = self.np_random.randint(low=0, high=1, size=(4,))
        #self.state = (1,2,3,3),(1,2,3,3)
      
       self.state = self.np_random.uniform(low=-0.05, high=0.05, size=(4,))
       self.steps_beyond_done = None
       return np.array(self.state, dtype=np.float32)

# %%
"""
Classic cart-pole system implemented by Rich Sutton et al.
Copied from http://incompleteideas.net/sutton/book/code/pole.c
permalink: https://perma.cc/C9ZM-652R
"""

import math
import gym
from gym import spaces, logger
from gym.utils import seeding
import numpy as np
import random


class CartPoleEnv3(gym.Env):
    """
    Description:
        A pole is attached by an un-actuated joint to a cart, which moves along
        a frictionless track. The pendulum starts upright, and the goal is to
        prevent it from falling over by increasing and reducing the cart's
        velocity.
    Source:
        This environment corresponds to the version of the cart-pole problem
        described by Barto, Sutton, and Anderson
    Observation:
        Type: Box(4)
        Num     Observation               Min                     Max
        0       Cart Position             -4.8                    4.8
        1       Cart Velocity             -Inf                    Inf
        2       Pole Angle                -0.418 rad (-24 deg)    0.418 rad (24 deg)
        3       Pole Angular Velocity     -Inf                    Inf
    Actions:
        Type: Discrete(2)
        Num   Action
        0     Push cart to the left
        1     Push cart to the right
        Note: The amount the velocity that is reduced or increased is not
        fixed; it depends on the angle the pole is pointing. This is because
        the center of gravity of the pole increases the amount of energy needed
        to move the cart underneath it
    Reward:
        Reward is 1 for every step taken, including the termination step
    Starting State:
        All observations are assigned a uniform random value in [-0.05..0.05]
    Episode Termination:
        Pole Angle is more than 12 degrees.
        Cart Position is more than 2.4 (center of the cart reaches the edge of
        the display).
        Episode length is greater than 200.
        Solved Requirements:
        Considered solved when the average return is greater than or equal to
        195.0 over 100 consecutive trials.
    """

    #metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 50}

    def __init__(self):
        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 1.0
        self.tau = 0.02  # seconds between state updates
        self.kinematics_integrator = "euler"

        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4

        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array(
            [
                1,
                100,
                100,
                100,
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.seed()
        self.viewer = None
        self.state = None

        self.steps_beyond_done = None

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def step(self, action):
        err_msg = "%r (%s) invalid" % (action, type(action))
        assert self.action_space.contains(action), err_msg

        x, x_dot, theta, theta_dot = self.state
        force = self.force_mag if action == 1 else -self.force_mag
        d=1
         
        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        
        #t=[1,5,4]
        reward=0
        a=8
        b=2
        k=0
        
        #for i in range(20):
        
        if  i==0:
            
            x = dot[0][k]
            x_dot =x_dot+dot[1][k]+d
            theta = 3
            theta_dot = 4
            k+=1
            
            
            
            d+=1
            reward = 1
        
        elif random.random()>math.exp(-a/b)and i!=0:
            x = 0
            d+=1*force
            x_dot =x_dot+d
            theta = 3
            theta_dot = 4
            k+=1
            d+=1*force
            
            
            
            reward = 1+d
            
            
           
            
        else:
            
            x=0
            x_dot = x_dot
            theta = 3
            theta_dot = 4
            reward = -(1+d)
            
            
            b+=1
            a-=1
        #if self.kinematics_integrator == "euler":
        #x = t[0][0]
        
          
        self.state = (x, x_dot, theta, theta_dot)

        done = bool(x_dot>100)
        
        a=a
        b=b
       
        

        return np.array(self.state, dtype=np.float32), reward, done, {}


    def reset(self):
        
        #self.state = self.np_random.randint(low=0, high=1, size=(4,))
       self.state = (0),(0),(0),(0)
      
       #self.state = self.np_random.uniform(low=0, high=0, size=(4,))
       #self.state=self.np.random.uniform(size = (4,), low = 0, high = 1)
       self.steps_beyond_done = None
       return np.array(self.state, dtype=np.float32)

# %%
"""
Classic cart-pole system implemented by Rich Sutton et al.
Copied from http://incompleteideas.net/sutton/book/code/pole.c
permalink: https://perma.cc/C9ZM-652R
"""

import math
import gym
from gym import spaces, logger
from gym.utils import seeding
import numpy as np


class CartPoleEnv2(gym.Env):
    """
    Description:
        A pole is attached by an un-actuated joint to a cart, which moves along
        a frictionless track. The pendulum starts upright, and the goal is to
        prevent it from falling over by increasing and reducing the cart's
        velocity.
    Source:
        This environment corresponds to the version of the cart-pole problem
        described by Barto, Sutton, and Anderson
    Observation:
        Type: Box(4)
        Num     Observation               Min                     Max
        0       Cart Position             -4.8                    4.8
        1       Cart Velocity             -Inf                    Inf
        2       Pole Angle                -0.418 rad (-24 deg)    0.418 rad (24 deg)
        3       Pole Angular Velocity     -Inf                    Inf
    Actions:
        Type: Discrete(2)
        Num   Action
        0     Push cart to the left
        1     Push cart to the right
        Note: The amount the velocity that is reduced or increased is not
        fixed; it depends on the angle the pole is pointing. This is because
        the center of gravity of the pole increases the amount of energy needed
        to move the cart underneath it
    Reward:
        Reward is 1 for every step taken, including the termination step
    Starting State:
        All observations are assigned a uniform random value in [-0.05..0.05]
    Episode Termination:
        Pole Angle is more than 12 degrees.
        Cart Position is more than 2.4 (center of the cart reaches the edge of
        the display).
        Episode length is greater than 200.
        Solved Requirements:
        Considered solved when the average return is greater than or equal to
        195.0 over 100 consecutive trials.
    """

    #metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 50}

    def __init__(self):
        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates
        self.kinematics_integrator = "euler"

        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4

        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array(
            [
                self.x_threshold * 2,
                np.finfo(np.float32).max,
                self.theta_threshold_radians * 2,
                np.finfo(np.float32).max,
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.seed()
        self.viewer = None
        self.state = None

        self.steps_beyond_done = None

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def step(self, action):
        #err_msg = "%r (%s) invalid" % (action, type(action))
        #assert self.action_space.contains(action), err_msg

        x, x_dot, theta, theta_dot = self.state
        force = self.force_mag if action == 1 else -self.force_mag
        costheta = math.cos(theta)
        sintheta = math.sin(theta)

        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        temp = (
            force + self.polemass_length * theta_dot ** 2 * sintheta
        ) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (
            self.length * (4.0 / 3.0 - self.masspole * costheta ** 2 / self.total_mass)
        )
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        if self.kinematics_integrator == "euler":
            x = x + self.tau * x_dot
            x_dot = x_dot + self.tau * xacc
            theta = theta + self.tau * theta_dot
            theta_dot = theta_dot + self.tau * thetaacc
        else:  # semi-implicit euler
            x_dot = x_dot + self.tau * xacc
            x = x + self.tau * x_dot
            theta_dot = theta_dot + self.tau * thetaacc
            theta = theta + self.tau * theta_dot

        self.state = (x, x_dot, theta, theta_dot)

        done = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        if not done:
            reward = 1.0
        elif self.steps_beyond_done is None:
            # Pole just fell!
            self.steps_beyond_done = 0
            reward = 1.0
        else:
            if self.steps_beyond_done == 0:
                logger.warn(
                    "You are calling 'step()' even though this "
                    "environment has already returned done = True. You "
                    "should always call 'reset()' once you receive 'done = "
                    "True' -- any further steps are undefined behavior."
                )
            self.steps_beyond_done += 1
            reward = 0.0

        return np.array(self.state, dtype=np.float32), reward, done, {}

    def reset(self):
        self.state = self.np_random.uniform(low=0.0, high=0.05, size=(4,))
        self.steps_beyond_done = None
        return np.array(self.state, dtype=np.float32)

# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np


class DeepQNetwork(nn.Module):
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims,
                 n_actions):
        super(DeepQNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)

        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)

        return actions


class Agent:
    def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions,
                 max_mem_size=100000, eps_end=0.05, eps_dec=5e-4):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)]
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        self.iter_cntr = 0
        self.replace_target = 100

        self.Q_eval = DeepQNetwork(lr, n_actions=n_actions,
                                   input_dims=input_dims,
                                   fc1_dims=256, fc2_dims=256)
        self.state_memory = np.zeros((self.mem_size, *input_dims),
                                     dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims),
                                         dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    def store_transition(self, state, action, reward, state_, terminal):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] = action
        self.terminal_memory[index] = terminal

        self.mem_cntr += 1

    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation]).to(self.Q_eval.device)
            actions = self.Q_eval.forward(state)
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    def learn(self):
        if self.mem_cntr < self.batch_size:
            return

        self.Q_eval.optimizer.zero_grad()

        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, self.batch_size, replace=False)
        batch_index = np.arange(self.batch_size, dtype=np.int32)

        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(
                self.new_state_memory[batch]).to(self.Q_eval.device)
        action_batch = self.action_memory[batch]
        reward_batch = T.tensor(
                self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(
                self.terminal_memory[batch]).to(self.Q_eval.device)

        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0

        q_target = reward_batch + self.gamma*T.max(q_next, dim=1)[0]

        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()

        self.iter_cntr += 1
        self.epsilon = self.epsilon - self.eps_dec \
            if self.epsilon > self.eps_min else self.eps_min

# %%
import matplotlib.pyplot as plt
import numpy as np
import gym

def plotLearning(x, scores, epsilons,lines=None):
    fig=plt.figure()
    ax=fig.add_subplot(111, label="1")
    ax2=fig.add_subplot(111, label="2", frame_on=False)

    ax.plot(x, epsilons, color="C0")
    ax.set_xlabel("Game", color="C0")
    ax.set_ylabel("Epsilon", color="C0")
    ax.tick_params(axis='x', colors="C0")
    ax.tick_params(axis='y', colors="C0")

    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
	    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])

    ax2.scatter(x, running_avg, color="C1")
    #ax2.xaxis.tick_top()
    ax2.axes.get_xaxis().set_visible(False)
    ax2.yaxis.tick_right()
    #ax2.set_xlabel('x label 2', color="C1")
    ax2.set_ylabel('Score', color="C1")
    #ax2.xaxis.set_label_position('top')
    ax2.yaxis.set_label_position('right')
    #ax2.tick_params(axis='x', colors="C1")
    ax2.tick_params(axis='y', colors="C1")

    if lines is not None:
        for line in lines:
            plt.axvline(x=line)

# %%
import gym
#from simple_dqn_torch_2020 import Agent
#from utils import plotLearning
import numpy as np

#t=[[0,5,4],[0,4,4],[0,3,4],[0,3,4],[0,3,4],[1,7,4],[1,8,4],[0,3,4],[0,8,4]]
if __name__ == '__main__':
    #env = gym.make('CartPole-v1')
    env=CartPoleEnv3()
    agent = Agent(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=2, eps_end=0.01,
                  input_dims=[4], lr=0.001)
    scores, eps_history = [], []
    n_games =500
    x_dot=20
    dot=[[1,20],[1,21],[1,22],[1,24],[1,25],[1,20],[1,21],[1,22],[1,24],[1,25],[1,20],[1,21],[1,22],[1,24],[1,25],[1,20],[1,21],[1,22],[1,24],[1,25]]
    
    for i in range(n_games):
        score = 0
        done = False
        observation = env.reset()
        #observation=env.step(action)
        
        while not done:
            
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            score += reward
            agent.store_transition(observation, action, reward, 
                                    observation_, done)
            agent.learn()
            observation = observation_
        scores.append(score)
        eps_history.append(agent.epsilon)
        
        avg_score = np.mean(scores[-100:])

        print('episode ', i, 'score %.2f' % score,
                'average score %.2f' % avg_score,
                'epsilon %.2f' % agent.epsilon)
    x = [i+1 for i in range(n_games)]
    #filename = 'lunar_lander.png'
    plotLearning(x, scores, eps_history)
# Out:
# episode  0 score 51.00 average score 51.00 epsilon 1.00
# episode  1 score 200.00 average score 125.50 epsilon 0.96
# episode  2 score 198.00 average score 149.67 epsilon 0.91
# episode  3 score 200.00 average score 162.25 epsilon 0.86
# episode  4 score 202.00 average score 170.20 epsilon 0.81
# episode  5 score 202.00 average score 175.50 epsilon 0.77
# episode  6 score 202.00 average score 179.29 epsilon 0.73
# episode  7 score 200.00 average score 181.88 epsilon 0.69
# episode  8 score 198.00 average score 183.67 epsilon 0.65
# episode  9 score 204.00 average score 185.70 epsilon 0.61
# episode  10 score 200.00 average score 187.00 epsilon 0.57
# episode  11 score 204.00 average score 188.42 epsilon 0.54
# episode  12 score 204.00 average score 189.62 epsilon 0.51
# episode  13 score 204.00 average score 190.64 epsilon 0.47
# episode  14 score 200.00 average score 191.27 epsilon 0.43
# episode  15 score 202.00 average score 191.94 epsilon 0.40
# episode  16 score 204.00 average score 192.65 epsilon 0.37
# episode  17 score 200.00 average score 193.06 epsilon 0.34
# episode  18 score 202.00 average score 193.53 epsilon 0.30
# episode  19 score 198.00 average score 193.75 epsilon 0.27
# episode  20 score 204.00 average score 194.24 epsilon 0.25
# episode  21 score 202.00 average score 194.59 epsilon 0.21
# episode  22 score 200.00 average score 194.83 epsilon 0.18
# episode  23 score 198.00 average score 194.96 epsilon 0.15
# episode  24 score 204.00 average score 195.32 epsilon 0.13
# episode  25 score 204.00 average score 195.65 epsilon 0.10
# episode  26 score 204.00 average score 195.96 epsilon 0.07
# episode  27 score 202.00 average score 196.18 epsilon 0.04
# episode  28 score 202.00 average score 196.38 epsilon 0.02
# episode  29 score 202.00 average score 196.57 epsilon 0.01
# episode  30 score 198.00 average score 196.61 epsilon 0.01
# episode  31 score 204.00 average score 196.84 epsilon 0.01
# episode  32 score 204.00 average score 197.06 epsilon 0.01
# episode  33 score 204.00 average score 197.26 epsilon 0.01
# episode  34 score 204.00 average score 197.46 epsilon 0.01
# episode  35 score 204.00 average score 197.64 epsilon 0.01
# episode  36 score 202.00 average score 197.76 epsilon 0.01
# episode  37 score 198.00 average score 197.76 epsilon 0.01
# episode  38 score 202.00 average score 197.87 epsilon 0.01
# episode  39 score 202.00 average score 197.97 epsilon 0.01
# episode  40 score 202.00 average score 198.07 epsilon 0.01
# episode  41 score 204.00 average score 198.21 epsilon 0.01
# episode  42 score 204.00 average score 198.35 epsilon 0.01
# episode  43 score 204.00 average score 198.48 epsilon 0.01
# episode  44 score 202.00 average score 198.56 epsilon 0.01
# episode  45 score 196.00 average score 198.50 epsilon 0.01
# episode  46 score 204.00 average score 198.62 epsilon 0.01
# episode  47 score 202.00 average score 198.69 epsilon 0.01
# episode  48 score 202.00 average score 198.76 epsilon 0.01
# episode  49 score 202.00 average score 198.82 epsilon 0.01
# episode  50 score 198.00 average score 198.80 epsilon 0.01
# episode  51 score 202.00 average score 198.87 epsilon 0.01
# episode  52 score 200.00 average score 198.89 epsilon 0.01
# episode  53 score 198.00 average score 198.87 epsilon 0.01
# episode  54 score 198.00 average score 198.85 epsilon 0.01
# episode  55 score 202.00 average score 198.91 epsilon 0.01
# episode  56 score 200.00 average score 198.93 epsilon 0.01
# episode  57 score 198.00 average score 198.91 epsilon 0.01
# episode  58 score 204.00 average score 199.00 epsilon 0.01
# episode  59 score 202.00 average score 199.05 epsilon 0.01
# episode  60 score 204.00 average score 199.13 epsilon 0.01
# episode  61 score 204.00 average score 199.21 epsilon 0.01
# episode  62 score 204.00 average score 199.29 epsilon 0.01
# episode  63 score 204.00 average score 199.36 epsilon 0.01
# episode  64 score 202.00 average score 199.40 epsilon 0.01
# episode  65 score 198.00 average score 199.38 epsilon 0.01
# episode  66 score 200.00 average score 199.39 epsilon 0.01
# episode  67 score 204.00 average score 199.46 epsilon 0.01
# episode  68 score 204.00 average score 199.52 epsilon 0.01
# episode  69 score 204.00 average score 199.59 epsilon 0.01
# episode  70 score 204.00 average score 199.65 epsilon 0.01
# episode  71 score 204.00 average score 199.71 epsilon 0.01
# episode  72 score 204.00 average score 199.77 epsilon 0.01
# episode  73 score 198.00 average score 199.74 epsilon 0.01
# episode  74 score 202.00 average score 199.77 epsilon 0.01
# episode  75 score 204.00 average score 199.83 epsilon 0.01
# episode  76 score 202.00 average score 199.86 epsilon 0.01
# episode  77 score 204.00 average score 199.91 epsilon 0.01
# episode  78 score 204.00 average score 199.96 epsilon 0.01
# episode  79 score 204.00 average score 200.01 epsilon 0.01
# episode  80 score 200.00 average score 200.01 epsilon 0.01
# episode  81 score 198.00 average score 199.99 epsilon 0.01
# episode  82 score 200.00 average score 199.99 epsilon 0.01
# episode  83 score 198.00 average score 199.96 epsilon 0.01
# episode  84 score 204.00 average score 200.01 epsilon 0.01
# episode  85 score 204.00 average score 200.06 epsilon 0.01
# episode  86 score 202.00 average score 200.08 epsilon 0.01
# episode  87 score 204.00 average score 200.12 epsilon 0.01
# episode  88 score 204.00 average score 200.17 epsilon 0.01
# episode  89 score 202.00 average score 200.19 epsilon 0.01
# episode  90 score 204.00 average score 200.23 epsilon 0.01
# episode  91 score 200.00 average score 200.23 epsilon 0.01
# episode  92 score 200.00 average score 200.23 epsilon 0.01
# episode  93 score 200.00 average score 200.22 epsilon 0.01
# episode  94 score 204.00 average score 200.26 epsilon 0.01
# episode  95 score 204.00 average score 200.30 epsilon 0.01
# episode  96 score 204.00 average score 200.34 epsilon 0.01
# episode  97 score 204.00 average score 200.38 epsilon 0.01
# episode  98 score 202.00 average score 200.39 epsilon 0.01
# episode  99 score 204.00 average score 200.43 epsilon 0.01
# episode  100 score 200.00 average score 201.92 epsilon 0.01
# episode  101 score 204.00 average score 201.96 epsilon 0.01
# episode  102 score 204.00 average score 202.02 epsilon 0.01
# episode  103 score 202.00 average score 202.04 epsilon 0.01
# episode  104 score 202.00 average score 202.04 epsilon 0.01
# episode  105 score 198.00 average score 202.00 epsilon 0.01
# episode  106 score 204.00 average score 202.02 epsilon 0.01
# episode  107 score 204.00 average score 202.06 epsilon 0.01
# episode  108 score 204.00 average score 202.12 epsilon 0.01
# episode  109 score 204.00 average score 202.12 epsilon 0.01
# episode  110 score 198.00 average score 202.10 epsilon 0.01
# episode  111 score 202.00 average score 202.08 epsilon 0.01
# episode  112 score 198.00 average score 202.02 epsilon 0.01
# episode  113 score 204.00 average score 202.02 epsilon 0.01
# episode  114 score 198.00 average score 202.00 epsilon 0.01
# episode  115 score 200.00 average score 201.98 epsilon 0.01
# episode  116 score 200.00 average score 201.94 epsilon 0.01
# episode  117 score 202.00 average score 201.96 epsilon 0.01
# episode  118 score 204.00 average score 201.98 epsilon 0.01
# episode  119 score 202.00 average score 202.02 epsilon 0.01
# episode  120 score 204.00 average score 202.02 epsilon 0.01
# episode  121 score 202.00 average score 202.02 epsilon 0.01
# episode  122 score 200.00 average score 202.02 epsilon 0.01
# episode  123 score 202.00 average score 202.06 epsilon 0.01
# episode  124 score 200.00 average score 202.02 epsilon 0.01
# episode  125 score 204.00 average score 202.02 epsilon 0.01
# episode  126 score 200.00 average score 201.98 epsilon 0.01
# episode  127 score 204.00 average score 202.00 epsilon 0.01
# episode  128 score 204.00 average score 202.02 epsilon 0.01
# episode  129 score 204.00 average score 202.04 epsilon 0.01
# episode  130 score 200.00 average score 202.06 epsilon 0.01
# episode  131 score 198.00 average score 202.00 epsilon 0.01
# episode  132 score 204.00 average score 202.00 epsilon 0.01
# episode  133 score 202.00 average score 201.98 epsilon 0.01
# episode  134 score 202.00 average score 201.96 epsilon 0.01
# episode  135 score 202.00 average score 201.94 epsilon 0.01
# episode  136 score 204.00 average score 201.96 epsilon 0.01
# episode  137 score 202.00 average score 202.00 epsilon 0.01
# episode  138 score 204.00 average score 202.02 epsilon 0.01
# episode  139 score 204.00 average score 202.04 epsilon 0.01
# episode  140 score 204.00 average score 202.06 epsilon 0.01
# episode  141 score 204.00 average score 202.06 epsilon 0.01
# episode  142 score 202.00 average score 202.04 epsilon 0.01
# episode  143 score 202.00 average score 202.02 epsilon 0.01
# episode  144 score 204.00 average score 202.04 epsilon 0.01
# episode  145 score 204.00 average score 202.12 epsilon 0.01
# episode  146 score 204.00 average score 202.12 epsilon 0.01
# episode  147 score 198.00 average score 202.08 epsilon 0.01
# episode  148 score 198.00 average score 202.04 epsilon 0.01
# episode  149 score 200.00 average score 202.02 epsilon 0.01
# episode  150 score 202.00 average score 202.06 epsilon 0.01
# episode  151 score 204.00 average score 202.08 epsilon 0.01
# episode  152 score 204.00 average score 202.12 epsilon 0.01
# episode  153 score 204.00 average score 202.18 epsilon 0.01
# episode  154 score 198.00 average score 202.18 epsilon 0.01
# episode  155 score 200.00 average score 202.16 epsilon 0.01
# episode  156 score 204.00 average score 202.20 epsilon 0.01
# episode  157 score 200.00 average score 202.22 epsilon 0.01
# episode  158 score 204.00 average score 202.22 epsilon 0.01
# episode  159 score 196.00 average score 202.16 epsilon 0.01
# episode  160 score 200.00 average score 202.12 epsilon 0.01
# episode  161 score 200.00 average score 202.08 epsilon 0.01
# episode  162 score 204.00 average score 202.08 epsilon 0.01
# episode  163 score 202.00 average score 202.06 epsilon 0.01
# episode  164 score 202.00 average score 202.06 epsilon 0.01
# episode  165 score 202.00 average score 202.10 epsilon 0.01
# episode  166 score 198.00 average score 202.08 epsilon 0.01
# episode  167 score 200.00 average score 202.04 epsilon 0.01
# episode  168 score 204.00 average score 202.04 epsilon 0.01
# episode  169 score 204.00 average score 202.04 epsilon 0.01
# episode  170 score 202.00 average score 202.02 epsilon 0.01
# episode  171 score 204.00 average score 202.02 epsilon 0.01
# episode  172 score 204.00 average score 202.02 epsilon 0.01
# episode  173 score 202.00 average score 202.06 epsilon 0.01
# episode  174 score 198.00 average score 202.02 epsilon 0.01
# episode  175 score 202.00 average score 202.00 epsilon 0.01
# episode  176 score 204.00 average score 202.02 epsilon 0.01
# episode  177 score 204.00 average score 202.02 epsilon 0.01
# episode  178 score 204.00 average score 202.02 epsilon 0.01
# episode  179 score 204.00 average score 202.02 epsilon 0.01
# episode  180 score 202.00 average score 202.04 epsilon 0.01
# episode  181 score 200.00 average score 202.06 epsilon 0.01
# episode  182 score 202.00 average score 202.08 epsilon 0.01
# episode  183 score 202.00 average score 202.12 epsilon 0.01
# episode  184 score 202.00 average score 202.10 epsilon 0.01
# episode  185 score 198.00 average score 202.04 epsilon 0.01
# episode  186 score 202.00 average score 202.04 epsilon 0.01
# episode  187 score 202.00 average score 202.02 epsilon 0.01
# episode  188 score 204.00 average score 202.02 epsilon 0.01
# episode  189 score 204.00 average score 202.04 epsilon 0.01
# episode  190 score 204.00 average score 202.04 epsilon 0.01
# episode  191 score 202.00 average score 202.06 epsilon 0.01
# episode  192 score 198.00 average score 202.04 epsilon 0.01
# episode  193 score 202.00 average score 202.06 epsilon 0.01
# episode  194 score 202.00 average score 202.04 epsilon 0.01
# episode  195 score 204.00 average score 202.04 epsilon 0.01
# episode  196 score 202.00 average score 202.02 epsilon 0.01
# episode  197 score 202.00 average score 202.00 epsilon 0.01
# episode  198 score 202.00 average score 202.00 epsilon 0.01
# episode  199 score 198.00 average score 201.94 epsilon 0.01
# episode  200 score 200.00 average score 201.94 epsilon 0.01
# episode  201 score 202.00 average score 201.92 epsilon 0.01
# episode  202 score 204.00 average score 201.92 epsilon 0.01
# episode  203 score 202.00 average score 201.92 epsilon 0.01
# episode  204 score 204.00 average score 201.94 epsilon 0.01
# episode  205 score 204.00 average score 202.00 epsilon 0.01
# episode  206 score 202.00 average score 201.98 epsilon 0.01
# episode  207 score 204.00 average score 201.98 epsilon 0.01
# episode  208 score 198.00 average score 201.92 epsilon 0.01
# episode  209 score 198.00 average score 201.86 epsilon 0.01
# episode  210 score 204.00 average score 201.92 epsilon 0.01
# episode  211 score 204.00 average score 201.94 epsilon 0.01
# episode  212 score 204.00 average score 202.00 epsilon 0.01
# episode  213 score 200.00 average score 201.96 epsilon 0.01
# episode  214 score 202.00 average score 202.00 epsilon 0.01
# episode  215 score 204.00 average score 202.04 epsilon 0.01
# episode  216 score 204.00 average score 202.08 epsilon 0.01
# episode  217 score 204.00 average score 202.10 epsilon 0.01
# episode  218 score 202.00 average score 202.08 epsilon 0.01
# episode  219 score 202.00 average score 202.08 epsilon 0.01
# episode  220 score 202.00 average score 202.06 epsilon 0.01
# episode  221 score 202.00 average score 202.06 epsilon 0.01
# episode  222 score 200.00 average score 202.06 epsilon 0.01
# episode  223 score 200.00 average score 202.04 epsilon 0.01
# episode  224 score 204.00 average score 202.08 epsilon 0.01
# episode  225 score 202.00 average score 202.06 epsilon 0.01
# episode  226 score 200.00 average score 202.06 epsilon 0.01
# episode  227 score 204.00 average score 202.06 epsilon 0.01
# episode  228 score 204.00 average score 202.06 epsilon 0.01
# episode  229 score 204.00 average score 202.06 epsilon 0.01
# episode  230 score 202.00 average score 202.08 epsilon 0.01
# episode  231 score 200.00 average score 202.10 epsilon 0.01
# episode  232 score 204.00 average score 202.10 epsilon 0.01
# episode  233 score 202.00 average score 202.10 epsilon 0.01
# episode  234 score 202.00 average score 202.10 epsilon 0.01
# episode  235 score 204.00 average score 202.12 epsilon 0.01
# episode  236 score 202.00 average score 202.10 epsilon 0.01
# episode  237 score 200.00 average score 202.08 epsilon 0.01
# episode  238 score 204.00 average score 202.08 epsilon 0.01
# episode  239 score 202.00 average score 202.06 epsilon 0.01
# episode  240 score 204.00 average score 202.06 epsilon 0.01
# episode  241 score 204.00 average score 202.06 epsilon 0.01
# episode  242 score 204.00 average score 202.08 epsilon 0.01
# episode  243 score 202.00 average score 202.08 epsilon 0.01
# episode  244 score 202.00 average score 202.06 epsilon 0.01
# episode  245 score 204.00 average score 202.06 epsilon 0.01
# episode  246 score 204.00 average score 202.06 epsilon 0.01
# episode  247 score 204.00 average score 202.12 epsilon 0.01
# episode  248 score 198.00 average score 202.12 epsilon 0.01
# episode  249 score 202.00 average score 202.14 epsilon 0.01
# episode  250 score 200.00 average score 202.12 epsilon 0.01
# episode  251 score 202.00 average score 202.10 epsilon 0.01
# episode  252 score 200.00 average score 202.06 epsilon 0.01
# episode  253 score 202.00 average score 202.04 epsilon 0.01
# episode  254 score 202.00 average score 202.08 epsilon 0.01
# episode  255 score 202.00 average score 202.10 epsilon 0.01
# episode  256 score 202.00 average score 202.08 epsilon 0.01
# episode  257 score 204.00 average score 202.12 epsilon 0.01
# episode  258 score 204.00 average score 202.12 epsilon 0.01
# episode  259 score 200.00 average score 202.16 epsilon 0.01
# episode  260 score 202.00 average score 202.18 epsilon 0.01
# episode  261 score 200.00 average score 202.18 epsilon 0.01
# episode  262 score 202.00 average score 202.16 epsilon 0.01
# episode  263 score 202.00 average score 202.16 epsilon 0.01
# episode  264 score 200.00 average score 202.14 epsilon 0.01
# episode  265 score 204.00 average score 202.16 epsilon 0.01
# episode  266 score 200.00 average score 202.18 epsilon 0.01
# episode  267 score 196.00 average score 202.14 epsilon 0.01
# episode  268 score 204.00 average score 202.14 epsilon 0.01
# episode  269 score 202.00 average score 202.12 epsilon 0.01
# episode  270 score 204.00 average score 202.14 epsilon 0.01
# episode  271 score 202.00 average score 202.12 epsilon 0.01
# episode  272 score 204.00 average score 202.12 epsilon 0.01
# episode  273 score 204.00 average score 202.14 epsilon 0.01
# episode  274 score 204.00 average score 202.20 epsilon 0.01
# episode  275 score 202.00 average score 202.20 epsilon 0.01
# episode  276 score 204.00 average score 202.20 epsilon 0.01
# episode  277 score 204.00 average score 202.20 epsilon 0.01
# episode  278 score 200.00 average score 202.16 epsilon 0.01
# episode  279 score 204.00 average score 202.16 epsilon 0.01
# episode  280 score 204.00 average score 202.18 epsilon 0.01
# episode  281 score 202.00 average score 202.20 epsilon 0.01
# episode  282 score 202.00 average score 202.20 epsilon 0.01
# episode  283 score 204.00 average score 202.22 epsilon 0.01
# episode  284 score 204.00 average score 202.24 epsilon 0.01
# episode  285 score 204.00 average score 202.30 epsilon 0.01
# episode  286 score 200.00 average score 202.28 epsilon 0.01
# episode  287 score 202.00 average score 202.28 epsilon 0.01
# episode  288 score 202.00 average score 202.26 epsilon 0.01
# episode  289 score 204.00 average score 202.26 epsilon 0.01
# episode  290 score 202.00 average score 202.24 epsilon 0.01
# episode  291 score 196.00 average score 202.18 epsilon 0.01
# episode  292 score 202.00 average score 202.22 epsilon 0.01
# episode  293 score 200.00 average score 202.20 epsilon 0.01
# episode  294 score 202.00 average score 202.20 epsilon 0.01
# episode  295 score 200.00 average score 202.16 epsilon 0.01
# episode  296 score 204.00 average score 202.18 epsilon 0.01
# episode  297 score 200.00 average score 202.16 epsilon 0.01
# episode  298 score 202.00 average score 202.16 epsilon 0.01
# episode  299 score 202.00 average score 202.20 epsilon 0.01
# episode  300 score 202.00 average score 202.22 epsilon 0.01
# episode  301 score 204.00 average score 202.24 epsilon 0.01
# episode  302 score 202.00 average score 202.22 epsilon 0.01
# episode  303 score 204.00 average score 202.24 epsilon 0.01
# episode  304 score 204.00 average score 202.24 epsilon 0.01
# episode  305 score 202.00 average score 202.22 epsilon 0.01
# episode  306 score 202.00 average score 202.22 epsilon 0.01
# episode  307 score 204.00 average score 202.22 epsilon 0.01
# episode  308 score 200.00 average score 202.24 epsilon 0.01
# episode  309 score 204.00 average score 202.30 epsilon 0.01
# episode  310 score 202.00 average score 202.28 epsilon 0.01
# episode  311 score 204.00 average score 202.28 epsilon 0.01
# episode  312 score 204.00 average score 202.28 epsilon 0.01
# episode  313 score 204.00 average score 202.32 epsilon 0.01
# episode  314 score 204.00 average score 202.34 epsilon 0.01
# episode  315 score 202.00 average score 202.32 epsilon 0.01
# episode  316 score 202.00 average score 202.30 epsilon 0.01
# episode  317 score 204.00 average score 202.30 epsilon 0.01
# episode  318 score 204.00 average score 202.32 epsilon 0.01
# episode  319 score 204.00 average score 202.34 epsilon 0.01
# episode  320 score 202.00 average score 202.34 epsilon 0.01
# episode  321 score 204.00 average score 202.36 epsilon 0.01
# episode  322 score 202.00 average score 202.38 epsilon 0.01
# episode  323 score 202.00 average score 202.40 epsilon 0.01
# episode  324 score 202.00 average score 202.38 epsilon 0.01
# episode  325 score 200.00 average score 202.36 epsilon 0.01
# episode  326 score 200.00 average score 202.36 epsilon 0.01
# episode  327 score 202.00 average score 202.34 epsilon 0.01
# episode  328 score 200.00 average score 202.30 epsilon 0.01
# episode  329 score 202.00 average score 202.28 epsilon 0.01
# episode  330 score 198.00 average score 202.24 epsilon 0.01
# episode  331 score 202.00 average score 202.26 epsilon 0.01
# episode  332 score 200.00 average score 202.22 epsilon 0.01
# episode  333 score 202.00 average score 202.22 epsilon 0.01
# episode  334 score 198.00 average score 202.18 epsilon 0.01
# episode  335 score 204.00 average score 202.18 epsilon 0.01
# episode  336 score 204.00 average score 202.20 epsilon 0.01
# episode  337 score 204.00 average score 202.24 epsilon 0.01
# episode  338 score 204.00 average score 202.24 epsilon 0.01
# episode  339 score 204.00 average score 202.26 epsilon 0.01
# episode  340 score 204.00 average score 202.26 epsilon 0.01
# episode  341 score 200.00 average score 202.22 epsilon 0.01
# episode  342 score 204.00 average score 202.22 epsilon 0.01
# episode  343 score 200.00 average score 202.20 epsilon 0.01
# episode  344 score 202.00 average score 202.20 epsilon 0.01
# episode  345 score 204.00 average score 202.20 epsilon 0.01
# episode  346 score 200.00 average score 202.16 epsilon 0.01
# episode  347 score 200.00 average score 202.12 epsilon 0.01
# episode  348 score 204.00 average score 202.18 epsilon 0.01
# episode  349 score 204.00 average score 202.20 epsilon 0.01
# episode  350 score 200.00 average score 202.20 epsilon 0.01
# episode  351 score 204.00 average score 202.22 epsilon 0.01
# episode  352 score 198.00 average score 202.20 epsilon 0.01
# episode  353 score 204.00 average score 202.22 epsilon 0.01
# episode  354 score 202.00 average score 202.22 epsilon 0.01
# episode  355 score 202.00 average score 202.22 epsilon 0.01
# episode  356 score 204.00 average score 202.24 epsilon 0.01
# episode  357 score 202.00 average score 202.22 epsilon 0.01
# episode  358 score 204.00 average score 202.22 epsilon 0.01
# episode  359 score 200.00 average score 202.22 epsilon 0.01
# episode  360 score 202.00 average score 202.22 epsilon 0.01
# episode  361 score 204.00 average score 202.26 epsilon 0.01
# episode  362 score 200.00 average score 202.24 epsilon 0.01
# episode  363 score 196.00 average score 202.18 epsilon 0.01
# episode  364 score 196.00 average score 202.14 epsilon 0.01
# episode  365 score 202.00 average score 202.12 epsilon 0.01
# episode  366 score 204.00 average score 202.16 epsilon 0.01
# episode  367 score 202.00 average score 202.22 epsilon 0.01
# episode  368 score 200.00 average score 202.18 epsilon 0.01
# episode  369 score 202.00 average score 202.18 epsilon 0.01
# episode  370 score 204.00 average score 202.18 epsilon 0.01
# episode  371 score 200.00 average score 202.16 epsilon 0.01
# episode  372 score 204.00 average score 202.16 epsilon 0.01
# episode  373 score 200.00 average score 202.12 epsilon 0.01
# episode  374 score 204.00 average score 202.12 epsilon 0.01
# episode  375 score 204.00 average score 202.14 epsilon 0.01
# episode  376 score 204.00 average score 202.14 epsilon 0.01
# episode  377 score 202.00 average score 202.12 epsilon 0.01
# episode  378 score 204.00 average score 202.16 epsilon 0.01
# episode  379 score 204.00 average score 202.16 epsilon 0.01
# episode  380 score 204.00 average score 202.16 epsilon 0.01
# episode  381 score 202.00 average score 202.16 epsilon 0.01
# episode  382 score 204.00 average score 202.18 epsilon 0.01
# episode  383 score 204.00 average score 202.18 epsilon 0.01
# episode  384 score 202.00 average score 202.16 epsilon 0.01
# episode  385 score 204.00 average score 202.16 epsilon 0.01
# episode  386 score 200.00 average score 202.16 epsilon 0.01
# episode  387 score 204.00 average score 202.18 epsilon 0.01
# episode  388 score 202.00 average score 202.18 epsilon 0.01
# episode  389 score 204.00 average score 202.18 epsilon 0.01
# episode  390 score 198.00 average score 202.14 epsilon 0.01
# episode  391 score 202.00 average score 202.20 epsilon 0.01
# episode  392 score 200.00 average score 202.18 epsilon 0.01
# episode  393 score 202.00 average score 202.20 epsilon 0.01
# episode  394 score 204.00 average score 202.22 epsilon 0.01
# episode  395 score 204.00 average score 202.26 epsilon 0.01
# episode  396 score 204.00 average score 202.26 epsilon 0.01
# episode  397 score 198.00 average score 202.24 epsilon 0.01
# episode  398 score 204.00 average score 202.26 epsilon 0.01
# episode  399 score 204.00 average score 202.28 epsilon 0.01
# episode  400 score 200.00 average score 202.26 epsilon 0.01
# episode  401 score 204.00 average score 202.26 epsilon 0.01
# episode  402 score 200.00 average score 202.24 epsilon 0.01
# episode  403 score 202.00 average score 202.22 epsilon 0.01
# episode  404 score 204.00 average score 202.22 epsilon 0.01
# episode  405 score 204.00 average score 202.24 epsilon 0.01
# episode  406 score 204.00 average score 202.26 epsilon 0.01
# episode  407 score 204.00 average score 202.26 epsilon 0.01
# episode  408 score 200.00 average score 202.26 epsilon 0.01
# episode  409 score 202.00 average score 202.24 epsilon 0.01
# episode  410 score 202.00 average score 202.24 epsilon 0.01
# episode  411 score 202.00 average score 202.22 epsilon 0.01
# episode  412 score 204.00 average score 202.22 epsilon 0.01
# episode  413 score 202.00 average score 202.20 epsilon 0.01
# episode  414 score 202.00 average score 202.18 epsilon 0.01
# episode  415 score 202.00 average score 202.18 epsilon 0.01
# episode  416 score 204.00 average score 202.20 epsilon 0.01
# episode  417 score 200.00 average score 202.16 epsilon 0.01
# episode  418 score 204.00 average score 202.16 epsilon 0.01
# episode  419 score 200.00 average score 202.12 epsilon 0.01
# episode  420 score 202.00 average score 202.12 epsilon 0.01
# episode  421 score 204.00 average score 202.12 epsilon 0.01
# episode  422 score 204.00 average score 202.14 epsilon 0.01
# episode  423 score 204.00 average score 202.16 epsilon 0.01
# episode  424 score 202.00 average score 202.16 epsilon 0.01
# episode  425 score 202.00 average score 202.18 epsilon 0.01
# episode  426 score 204.00 average score 202.22 epsilon 0.01
# episode  427 score 204.00 average score 202.24 epsilon 0.01
# episode  428 score 204.00 average score 202.28 epsilon 0.01
# episode  429 score 200.00 average score 202.26 epsilon 0.01
# episode  430 score 200.00 average score 202.28 epsilon 0.01
# episode  431 score 202.00 average score 202.28 epsilon 0.01
# episode  432 score 202.00 average score 202.30 epsilon 0.01
# episode  433 score 200.00 average score 202.28 epsilon 0.01
# episode  434 score 202.00 average score 202.32 epsilon 0.01
# episode  435 score 202.00 average score 202.30 epsilon 0.01
# episode  436 score 200.00 average score 202.26 epsilon 0.01
# episode  437 score 204.00 average score 202.26 epsilon 0.01
# episode  438 score 196.00 average score 202.18 epsilon 0.01
# episode  439 score 202.00 average score 202.16 epsilon 0.01
# episode  440 score 204.00 average score 202.16 epsilon 0.01
# episode  441 score 202.00 average score 202.18 epsilon 0.01
# episode  442 score 202.00 average score 202.16 epsilon 0.01
# episode  443 score 200.00 average score 202.16 epsilon 0.01
# episode  444 score 198.00 average score 202.12 epsilon 0.01
# episode  445 score 204.00 average score 202.12 epsilon 0.01
# episode  446 score 204.00 average score 202.16 epsilon 0.01
# episode  447 score 202.00 average score 202.18 epsilon 0.01
# episode  448 score 200.00 average score 202.14 epsilon 0.01
# episode  449 score 202.00 average score 202.12 epsilon 0.01
# episode  450 score 204.00 average score 202.16 epsilon 0.01
# episode  451 score 196.00 average score 202.08 epsilon 0.01
# episode  452 score 202.00 average score 202.12 epsilon 0.01
# episode  453 score 204.00 average score 202.12 epsilon 0.01
# episode  454 score 202.00 average score 202.12 epsilon 0.01
# episode  455 score 204.00 average score 202.14 epsilon 0.01
# episode  456 score 200.00 average score 202.10 epsilon 0.01
# episode  457 score 202.00 average score 202.10 epsilon 0.01
# episode  458 score 202.00 average score 202.08 epsilon 0.01
# episode  459 score 200.00 average score 202.08 epsilon 0.01
# episode  460 score 202.00 average score 202.08 epsilon 0.01
# episode  461 score 202.00 average score 202.06 epsilon 0.01
# episode  462 score 204.00 average score 202.10 epsilon 0.01
# episode  463 score 204.00 average score 202.18 epsilon 0.01
# episode  464 score 204.00 average score 202.26 epsilon 0.01
# episode  465 score 198.00 average score 202.22 epsilon 0.01
# episode  466 score 204.00 average score 202.22 epsilon 0.01
# episode  467 score 202.00 average score 202.22 epsilon 0.01
# episode  468 score 204.00 average score 202.26 epsilon 0.01
# episode  469 score 204.00 average score 202.28 epsilon 0.01
# episode  470 score 204.00 average score 202.28 epsilon 0.01
# episode  471 score 200.00 average score 202.28 epsilon 0.01
# episode  472 score 202.00 average score 202.26 epsilon 0.01
# episode  473 score 200.00 average score 202.26 epsilon 0.01
# episode  474 score 202.00 average score 202.24 epsilon 0.01
# episode  475 score 204.00 average score 202.24 epsilon 0.01
# episode  476 score 204.00 average score 202.24 epsilon 0.01
# episode  477 score 204.00 average score 202.26 epsilon 0.01
# episode  478 score 204.00 average score 202.26 epsilon 0.01
# episode  479 score 204.00 average score 202.26 epsilon 0.01
# episode  480 score 196.00 average score 202.18 epsilon 0.01
# episode  481 score 200.00 average score 202.16 epsilon 0.01
# episode  482 score 204.00 average score 202.16 epsilon 0.01
# episode  483 score 200.00 average score 202.12 epsilon 0.01
# episode  484 score 202.00 average score 202.12 epsilon 0.01
# episode  485 score 204.00 average score 202.12 epsilon 0.01
# episode  486 score 202.00 average score 202.14 epsilon 0.01
# episode  487 score 204.00 average score 202.14 epsilon 0.01
# episode  488 score 204.00 average score 202.16 epsilon 0.01
# episode  489 score 198.00 average score 202.10 epsilon 0.01
# episode  490 score 202.00 average score 202.14 epsilon 0.01
# episode  491 score 204.00 average score 202.16 epsilon 0.01
# episode  492 score 204.00 average score 202.20 epsilon 0.01
# episode  493 score 200.00 average score 202.18 epsilon 0.01
# episode  494 score 204.00 average score 202.18 epsilon 0.01
# episode  495 score 204.00 average score 202.18 epsilon 0.01
# episode  496 score 200.00 average score 202.14 epsilon 0.01
# episode  497 score 204.00 average score 202.20 epsilon 0.01
# episode  498 score 202.00 average score 202.18 epsilon 0.01
# episode  499 score 204.00 average score 202.18 epsilon 0.01

# %%
import random
t=[[1,5,4],[1,4,4],[1,3,4],[1,3,4],[1,3,4],[1,7,4],[1,8,4],[1,3,4],[1,8,4]]
for i in range(len(t)):
  r=random.choices(t)
  if random.random()<.5:
        if r[0][0]==1 and random.random()<math.exp(-1):
          print(r[0][1])
  else:
    print('wrong')

# %%
r=math.exp(-1)
print(r)

# %%
t=[[1,5,4],[1,4,4],[1,3,4],[1,3,4],[1,3,4],[1,7,4],[1,8,4],[1,3,4],[1,8,4]]
for i in range(len(t)):
    x=t[i][0]+5
    t[i][0]=x
    print(t[i][0])

# %%
t=[[1,5,4],[1,4,4],[1,3,4],[1,3,4],[1,3,4],[0,7,4],[1,8,4],[1,3,4],[1,8,4]]

a=0
for i in range(len(t)):
  if t[i][0]==1:
     a-=1
    
    
print(a)

# %%
 a=0
         for i in range(len(t)):
           if t[i][0]==1:
              a+=1
         b=9-a

# %%
np.zeros((5,3), dtype=int)

# %%
[3]*[3]

# %%
# %history -g -f MDP_IOT

# %%
# %history -g

# %%
state = np_random.uniform(low=0, high=1, size=(4,))

# %%
for i in range(100):
 print(random.random())
